# %% [markdown]
# # 07 — Nhánh A: so sánh mô hình và backtest

# %% [markdown]
# Xem `docs/ban-do-tri-thuc-luan-van-du-bao-tu-vong.md`, Mục 12.1 và 13.
#
# - Dữ liệu tham chiếu HMD (Nhật Bản, Hàn Quốc, Đài Loan): `python -m src.data.make_dataset --dataset hmd_jpn`
#   rồi `Rscript R/02a_fit_lc.R hmd_jpn` ... (dataset là tham số dòng lệnh của mọi script R).
# - Backtest (`R/04_backtest.R`, danh sách mô hình ở `backtest.models`): RMSE/MAE trên log m, sai số
#   e₀/e₆₀, độ phủ khoảng dự báo 95% (`src.evaluation.metrics.coverage`), độ bền, tính hợp lý sinh học.
# - Phân tích riêng ảnh hưởng các năm COVID (2020–2022).
# - Kết luận: xếp hạng mô hình theo BIC và sai số backtest.

# %%
# %load_ext autoreload
# %autoreload 2

import sys
from pathlib import Path

ROOT = Path.cwd().resolve()
if not (ROOT / "src").exists():
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
