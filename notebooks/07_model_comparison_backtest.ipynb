# %% [markdown]
# # 07 — So sánh mô hình và backtest

# %% [markdown]
# **Bảng kết quả chính của luận văn:**
# - In-sample: AIC, BIC, deviance
# - Out-of-sample (các split trong config): RMSE (log scale), MAPE — theo từng mô hình, từng nhóm tuổi
# - Phân tích riêng ảnh hưởng các năm COVID (2020–2022)
# - Kết luận: đề xuất mô hình phù hợp nhất cho dữ liệu VN

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().resolve()
if not (ROOT / "src").exists():
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
