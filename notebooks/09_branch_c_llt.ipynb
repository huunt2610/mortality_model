# %% [markdown]
# # 09 — Nhánh C: Lee-Carter kiểu LLT trên bảng sống TCTK

# %% [markdown]
# Xem `docs/ban-do-tri-thuc-luan-van-du-bao-tu-vong.md`, Mục 12.3. Fit bằng `R/05_fit_llt.R` (đang là khung, chưa cài đặt).
#
# - Khớp trên các bảng 1989 (nếu có), 1999, 2009; dự báo 2014, 2019, 2024.
# - RWD với phương sai tỷ lệ khoảng cách thời gian giữa các lần quan sát.
# - So sánh sai số với nhánh B trên cùng điểm kiểm chứng; báo cáo trung thực khoảng dự báo rộng.

# %%
# %load_ext autoreload
# %autoreload 2

import sys
from pathlib import Path

ROOT = Path.cwd().resolve()
if not (ROOT / "src").exists():
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
