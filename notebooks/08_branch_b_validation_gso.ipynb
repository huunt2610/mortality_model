# %% [markdown]
# # 08 — Nhánh B: dự báo từ WPP so với bảng sống chính thức (TCTK)

# %% [markdown]
# Xem `docs/ban-do-tri-thuc-luan-van-du-bao-tu-vong.md`, Mục 12.2.
#
# 1. **Hài hoà nhóm tuổi:** gộp dự báo tuổi đơn về khuôn nhóm tuổi GSO -
#    `src.demography.age_groups.aggregate_qx_to_groups` (₅qₓ = 1 − Π(1 − qₓ₊ᵢ)); nhóm mở so sánh bằng eₓ.
# 2. **So sánh** trên ₙqₓ, e₀, e₆₀/e₆₅ tại các năm `validation.gso_years` (tầm 1, 6, 11, 16 năm).
# 3. **Phân rã sai số** (F − G) = (F − W) + (W − G): `src.evaluation.decomposition.decompose_error` -
#    báo cáo theo từng tầm dự báo, từng mô hình.
# 4. **Rò rỉ thông tin** (WPP 2024 đã thấy TĐT 2009, 2019) và **xử lý COVID**: phân tích độ nhạy.

# %%
# %load_ext autoreload
# %autoreload 2

import sys
from pathlib import Path

ROOT = Path.cwd().resolve()
if not (ROOT / "src").exists():
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
