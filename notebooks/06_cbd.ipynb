# %% [markdown]
# # 06 — Họ CBD: Cairns-Blake-Dowd (M5) và M7

# %% [markdown]
# Đọc `results/wpp_vnm/params_{cbd,m7}_*.csv` (`R/02c_fit_cbd.R`, `R/02e_fit_m7.R`).
#
# - Fit trên tuổi 55–90 (link logit, q(x,t)). Trình bày κ⁽¹⁾ (mức), κ⁽²⁾ (độ dốc).
# - So sánh với LC/RH ở nhóm tuổi già phải đổi về cùng đại lượng: q ≈ 1 − exp(−m).
# - M7 tùy chọn (Mục 19 - "hướng phát triển"); [CẦN KIỂM TRA] công thức M7 với Cairns và cộng sự (2009).

# %%
# %load_ext autoreload
# %autoreload 2

import sys
from pathlib import Path

ROOT = Path.cwd().resolve()
if not (ROOT / "src").exists():
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
