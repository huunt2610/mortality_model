# %% [markdown]
# # 06 — Mô hình Cairns-Blake-Dowd

# %% [markdown]
# Fit trên tuổi 55–90 (link logit). Trình bày kt1 (level), kt2 (slope); so sánh chất lượng fit ở nhóm tuổi già với LC/RH.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().resolve()
if not (ROOT / "src").exists():
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
