# %% [markdown]
# # 08 — Ứng dụng quản trị rủi ro bảo hiểm

# %% [markdown]
# Từ mortality dự báo (models/forecasts.rds → CSV):
# - e0, e60 dự báo kèm khoảng tin cậy (fan chart)
# - Phí thuần bảo hiểm tử kỳ 10 năm và annuity trọn đời mẫu theo từng mô hình
# - Chênh lệch phí/dự phòng giữa các mô hình = thước đo model risk
# - Thảo luận longevity risk trong khung Solvency II / IFRS 17

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().resolve()
if not (ROOT / "src").exists():
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
