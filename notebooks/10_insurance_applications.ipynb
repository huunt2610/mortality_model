# %% [markdown]
# # 10 — Ứng dụng quản trị rủi ro bảo hiểm

# %% [markdown]
# Xem `docs/ban-do-tri-thuc-luan-van-du-bao-tu-vong.md`, Mục 14. Kịch bản từ `R/06_simulate_scenarios.R` (đang là khung).
#
# 1. Mô phỏng `application.n_scenarios` kịch bản, có bootstrap bất định tham số.
# 2. Điều chỉnh sang người được bảo hiểm: hệ số `application.insured_factors` (phân tích độ nhạy).
# 3. Định giá theo bảng đoàn hệ: ä₆₅ (niên kim trọn đời), A¹ tử kỳ 20 năm tuổi 35 -
#    `src.risk.pricing` (`cohort_qx`, `annuity_due`, `term_insurance`).
# 4. Đo rủi ro: kỳ vọng, VaR 99,5%, ES, vốn rủi ro - `src.risk.measures`.
# 5. So sánh với CSO 1980; định lượng ba khoảng cách: CSO vs dự báo, mô hình vs mô hình, WPP vs LLT.
#
# [CẦN KIỂM TRA] lãi suất kỹ thuật tối đa và ngưỡng % so với CSO 1980 hiện hành (`application.interest_rate`).

# %%
# %load_ext autoreload
# %autoreload 2

import sys
from pathlib import Path

ROOT = Path.cwd().resolve()
if not (ROOT / "src").exists():
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
