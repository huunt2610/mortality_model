# %% [markdown]
# # 05 — Mô hình có đoàn hệ: Renshaw-Haberman (M2) và APC (M3)

# %% [markdown]
# Đọc `results/wpp_vnm/params_{rh,apc}_*.csv` (ghi bởi `R/02b_fit_rh.R`, `R/02d_fit_apc.R`).
#
# - Trình bày γ_c ước lượng được; tính hội tụ của RH (`conv`), độ bền khi dịch cửa sổ khớp.
# - So sánh RH với APC (ổn định hơn) và LC theo AIC/BIC và bản đồ nhiệt phần dư.
# - **Không diễn giải γ_c như dấu vết lịch sử** (chiến tranh, y tế): hình dạng tuổi trong WPP
#   được neo vào HMD qua mô hình Log-Quad, cohort effect có thể là sản phẩm của làm trơn -
#   xem `docs/ban-do-tri-thuc-luan-van-du-bao-tu-vong.md`, Mục 4.2 và 8.2.

# %%
# %load_ext autoreload
# %autoreload 2

import sys
from pathlib import Path

ROOT = Path.cwd().resolve()
if not (ROOT / "src").exists():
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
