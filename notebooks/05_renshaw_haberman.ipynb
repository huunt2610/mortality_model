# %% [markdown]
# # 05 — Mô hình Renshaw-Haberman

# %% [markdown]
# Trình bày gamma_c (cohort effect) ước lượng được; thảo luận: (1) tính hội tụ, (2) cohort effect trên dữ liệu UN đã làm trơn có thể là artifact — đối chiếu với các mốc lịch sử VN (chiến tranh, cải thiện y tế) để đánh giá tính hợp lý.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().resolve()
if not (ROOT / "src").exists():
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
